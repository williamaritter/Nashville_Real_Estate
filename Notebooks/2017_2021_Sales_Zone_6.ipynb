# %%
import pandas as pd
import glob
import pandas as pd
import json
import time
import matplotlib.pyplot as plt
import re

# %matplotlib inline

# %%
[pd.read_excel(file) for file in glob.glob('../data/*.xlsx')]
# Out:
# C:\Users\dataa\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# [           Parcel ID       Land Use     Property Address Suite/ Condo   #  \
#  0    026 00 0 020.00  SINGLE FAMILY     125  LIBERTY  LN              NaN
#  1    026 07 0 098.00  SINGLE FAMILY   116  CORBRIDGE  CT              NaN
#  2    026 15 0 028.00  SINGLE FAMILY     2305  MARSHA  DR              NaN
#  3    034 03 0 032.00  SINGLE FAMILY      2016  PAULA  DR              NaN
#  4   034 07 0B 020.00  SINGLE FAMILY  2504  VAL MARIE  DR              NaN
#  ..               ...            ...                  ...              ...
#  88   083 09 0 414.00  SINGLE FAMILY   1405  WOODLAND  ST              NaN
#  89   083 10 0 461.00  SINGLE FAMILY    1809  MCEWEN  AVE              NaN
#  90   084 01 0 117.00  SINGLE FAMILY   901  ROSEBANK  AVE              NaN
# ...
