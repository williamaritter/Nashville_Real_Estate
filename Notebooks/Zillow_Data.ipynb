# %%
import pandas as pd
import json
import time
import matplotlib.pyplot as plt
import re

# %matplotlib inline

import json

# %%
API_Key = json.load(open("../Data/API_Key.json"))["NashRE"]

# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"nashville, tn","home_type":"Houses"}

headers = {
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com",
	"X-RapidAPI-Key": API_Key}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"props":[{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":6969.6,"address":"1502 16th Ave N, Nashville, TN 37208","daysOnZillow":-1,"price":475000,"listingDateTime":null,"longitude":-86.80371,"latitude":36.1737,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"41098864","listingSubType":{"is_FSBA":true},"imgSrc":"https:\/\/photos.zillowstatic.com\/fp\/a5574fc5d61d92121acd187e8a536125-p_e.jpg","livingArea":1840,"bathrooms":3,"lotAreaUnit":"sqft","country":"USA","currency":"USD","bedrooms":3,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":5.02,"address":"8375 Old Pond Creek Rd, Pegram, TN 37143","daysOnZillow":-1,"price":284900,"listingDateTime":null,"longitude":-86.99556,"latitude":36.139008,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"108778636","listingSubType":{"is_foreclosure":true},"imgSrc":"https:\/\/photos.zillowstatic.com\/fp\/f739c79bc58184a0c9293d610d9863fc-p_e.jpg","livingArea":1144,"bathrooms":
# ...

# %%
type(response)
# Out:
# requests.models.Response

# %%
len(response.json())
# Out:
# 4

# %%
response.json().keys()
# Out:
# dict_keys(['props', 'resultsPerPage', 'totalResultCount', 'totalPages'])

# %%
response.json()['props'][39]
# Out:
# {'dateSold': None,
#  'propertyType': 'SINGLE_FAMILY',
#  'lotAreaValue': 8276.4,
#  'address': '730 Ringgold Dr, Nashville, TN 37207',
#  'daysOnZillow': -1,
#  'price': 325000,
#  'listingDateTime': None,
#  'longitude': -86.81313,
#  'latitude': 36.218246,
#  'contingentListingType': None,
#  'listingStatus': 'FOR_SALE',
#  'zpid': '41072523',
#  'listingSubType': {'is_FSBA': True},
#  'imgSrc': 'https://photos.zillowstatic.com/fp/95fa17d2ff4c121ec24eec74029b0b5a-p_e.jpg',
#  'livingArea': 2100,
#  'bathrooms': 1,
#  'lotAreaUnit': 'sqft',
#  'country': 'USA',
#  'currency': 'USD',
#  'bedrooms': 2,
#  'hasImage': True}

# %%
all_data = pd.DataFrame(response.json())

# %%
all_data.to_csv('all_data')

# %%
test = pd.read_csv("all_data")

# %%
test
# Out:
#     Unnamed: 0                                              props  \
# 0            0  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 1            1  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 2            2  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 3            3  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 4            4  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 5            5  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 6            6  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 7            7  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 8            8  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 9            9  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 10          10  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 11          11  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 12          12  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# ...

# %%
all_data
# Out:
#                                                 props  resultsPerPage  \
# 0   {'dateSold': None, 'propertyType': 'SINGLE_FAM...              40
# 1   {'dateSold': None, 'propertyType': 'SINGLE_FAM...              40
# 2   {'dateSold': None, 'propertyType': 'SINGLE_FAM...              40
# 3   {'dateSold': None, 'propertyType': 'SINGLE_FAM...              40
# 4   {'dateSold': None, 'propertyType': 'SINGLE_FAM...              40
# 5   {'dateSold': None, 'propertyType': 'SINGLE_FAM...              40
# 6   {'dateSold': None, 'propertyType': 'SINGLE_FAM...              40
# 7   {'dateSold': None, 'propertyType': 'SINGLE_FAM...              40
# 8   {'dateSold': None, 'propertyType': 'SINGLE_FAM...              40
# 9   {'dateSold': None, 'propertyType': 'SINGLE_FAM...              40
# 10  {'dateSold': None, 'propertyType': 'SINGLE_FAM...              40
# 11  {'dateSold': None, 'propertyType': 'SINGLE_FAM...              40
# ...
