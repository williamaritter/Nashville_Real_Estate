# %%
import pandas as pd
import json
import time
import matplotlib.pyplot as plt
import re

# %matplotlib inline

# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"nashville, tn","home_type":"Houses"}

headers = {
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com",
	"X-RapidAPI-Key": "225aae5b96msh7d82b1b54e263f1p19390fjsn7bba2aece94c"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"props":[{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":0.27,"address":"245 Collier Ave, Nashville, TN 37211","daysOnZillow":-1,"price":474900,"listingDateTime":null,"longitude":-86.73757,"latitude":36.108982,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"41150518","listingSubType":{"is_FSBA":true},"imgSrc":"https:\/\/photos.zillowstatic.com\/fp\/6518c79621c83d9fc4101f6ed1e0caec-p_e.jpg","livingArea":1374,"bathrooms":2,"lotAreaUnit":"acres","country":"USA","currency":"USD","bedrooms":3,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":0.34,"address":"3808 Anderson Rd, Nashville, TN 37217","daysOnZillow":-1,"price":415000,"listingDateTime":null,"longitude":-86.60346,"latitude":36.098846,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"41166527","listingSubType":{"is_FSBA":true},"imgSrc":"https:\/\/photos.zillowstatic.com\/fp\/f4a45e46d9186082c86f9b4857eeac08-p_e.jpg","livingArea":1785,"bathrooms":2,"lotAreaUnit":"acres","country":"USA","currency":"USD","bedrooms":3,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":10018.8,"address":"4304 Central Valley Dr, Hermitage, TN 37076","daysOnZillow":-1,"price":320000,"listingDateTime":null,"longitude":-86.59071,"latitude":36.17381,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"41110105","listingSubType":{"is_comingSoon":true},"imgSrc":"https:\/\/photos.zillowstatic.com\/fp\/bf6ac24c95ec755a7b9cb7e88843991e-p_e.jpg","livingArea":1159,"bathrooms":2,"lotAreaUnit":"sqft","country":"USA","currency":"USD","bedrooms":3,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":8712,"address":"5157 Pebble Creek Dr, Antioch, TN 37013","daysOnZillow":-1,"price":400000,"listingDateTime":null,"longitude":-86.649445,"latitude":36.071194,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"71261045","listingSubType":{"is_FSBA":true,"is_openHouse":true},"imgSrc":"https:\/\/photos.zillowstatic.com\/fp\/86d8f07b804db98d64503983e5324026-p_e.jpg","livingArea":1936,"bathrooms":3,"lotAreaUnit":"sqft","country":"USA","currency":"USD","bedrooms":4,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":6969.6,"address":"3208 Holland Ln, Nashville, TN 37218","daysOnZillow":-1,"price":245000,"listingDateTime":null,"longitude":-86.84204,"latitude":36.180412,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"41095579","listingSubType":{"is_FSBA":true},"imgSrc":"https:\/\/photos.zillowstatic.com\/fp\/7b4a45c42ddb7f54d721a16aa763d4c3-p_e.jpg","livingArea":1546,"bathrooms":2,"lotAreaUnit":"sqft","country":"USA","currency":"USD","bedrooms":3,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":0.45,"address":"926 Woods Lake Dr, Madison, TN 37115","daysOnZillow":-1,"price":325000,"listingDateTime":null,"longitude":-86.72701,"latitude":36.279278,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"41056740","listingSubType":{"is_FSBA":true},"imgSrc":"https:\/\/photos.zillowstatic.com\/fp\/615d16c342dd9f7418f809717d420ed0-p_e.jpg","livingArea":950,"bathrooms":1,"lotAreaUnit":"acres","country":"USA","currency":"USD","bedrooms":3,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":0.86,"address":"313 Hadley Ave, Old Hickory, TN 37138","daysOnZillow":-1,"price":495000,"listingDateTime":null,"longitude":-86.646774,"latitude":36.267475,"contingentListingType":null,"listingStatus":"FOR_SALE","zpid":"41060940","listingSubType":{"is_FSBA":true},"imgSrc":"https:\/\/photos.zillowstatic.com\/fp\/c11364622fb2770a41e83c9ca18244e9-p_e.jpg","livingArea":2384,"bathrooms":2,"lotAreaUnit":"acres","country":"USA","currency":"USD","bedrooms":3,"hasImage":true},{"dateSold":null,"propertyType":"SINGLE_FAMILY","lotAreaValue":0.32,"address":"260 Blackman Rd, Nashville, TN 37211","daysOnZillow":-1,"price":575000,"listingDateTime":null,"longitude":-86.74026,"latitude":36.074593,"contingen ...

# %%
type(response)
# Out:
# requests.models.Response

# %%
len(response.json())
# Out:
# 4

# %%
response.json().keys()
# Out:
# dict_keys(['props', 'resultsPerPage', 'totalResultCount', 'totalPages'])

# %%
response.json()['props'][39]
# Out:
# {'dateSold': None,
#  'propertyType': 'SINGLE_FAMILY',
#  'lotAreaValue': None,
#  'address': 'Aspen Plan, Thornton Grove',
#  'daysOnZillow': -1,
#  'price': 433990,
#  'listingDateTime': None,
#  'longitude': -86.7778,
#  'latitude': 36.253044,
#  'contingentListingType': None,
#  'listingStatus': 'FOR_SALE',
#  'zpid': '2078100250',
#  'listingSubType': {'is_newHome': True},
#  'imgSrc': 'https://photos.zillowstatic.com/fp/0bfea540d62821eaca1478633d1cf592-p_e.jpg',
#  'livingArea': 1440,
#  'bathrooms': 2,
#  'lotAreaUnit': None,
#  'country': 'USA',
#  'currency': 'USD',
#  'bedrooms': 3,
#  'hasImage': True}

# %%
all_data = pd.DataFrame(response.json())

# %%
all_data.to_csv('all_data')

# %%
test = pd.read_csv("all_data")

# %%
test
# Out:
#     Unnamed: 0                                              props  \
# 0            0  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 1            1  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 2            2  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 3            3  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 4            4  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 5            5  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 6            6  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 7            7  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 8            8  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 9            9  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 10          10  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 11          11  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 12          12  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 13          13  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 14          14  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 15          15  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 16          16  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 17          17  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 18          18  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 19          19  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 20          20  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 21          21  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 22          22  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 23          23  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 24          24  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 25          25  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 26          26  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 27          27  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 28          28  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 29          29  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 30          30  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 31          31  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 32          32  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 33          33  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 34          34  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 35          35  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 36          36  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 37          37  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 38          38  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
# 39          39  {'dateSold': None, 'propertyType': 'SINGLE_FAM...
#
#     resultsPerPage  totalResultCount  totalPages
# 0               40               530          14
# 1               40               530          14
# 2               40               530          14
# 3               40               530          14
# 4               40               530          14
# 5               40               530          14
# 6               40               530          14
# 7               40               530          14
# 8               40               530          14
# 9               40               530          14
# 10              40               530          14
# 11              40               530          14
# 12              40               530          14
# 13              40               530          14
# 14              40               530          14
# 15              40               530          14
# 16              40               530          14
# 17              40               530          14
# 18              40               530          14
# 19              40               530          14
# 20              40               530          14
# 21              40               530          14
# 22              40               530          14
# 23              40               530          14
# 24              40               530          14
# 25              40               530          14
# 26              40               530          14
# 27              40               530          14
# 28              40               530          14
# 29              40               530          14
# 30              40               530          14
# 31              40               530          14
# 32              40               530          14
# 33              40               530          14
# 34              40               530          14
# 35              40               530          14
# 36              40               530          14
# 37              40               530          14
# 38              40               530          14
# 39              40               530          14
